# %% [markdown]
# ## Tutorial on BlueSky tiled - Lazy loading of data
# - connect to client
# - list all folders(users)
# - choose a user: example: ahoust17
#     - choose a date
#     - view all files
#     - lazy loading of data

# %% [markdown]
# ### Enter your Tiled API key
#
# Before running the next cell, make sure you have a valid **Tiled API key** for the server.
#
# The next cell will ask you to enter the key securely, like a password.
# When prompted, paste your API key and press **Enter**.
#
# This will store the key temporarily as an environment variable named:
#
# `TILED_API_KEY`
#
# After entering the key, run the following cells to connect to the Tiled server.

# %%
import os
from getpass import getpass

os.environ["TILED_API_KEY"] = getpass("Enter your Tiled API key: ")

# %%
import os
from tiled.client import from_uri

client = from_uri(
    "http://10.46.217.241:9091",
    api_key=os.environ["TILED_API_KEY"],
)

list(client)
# Out:
# ['0032 - Nano HAADF STEM Diffraction.emd',
#  '0033 - Nano HAADF STEM Diffraction.emd',
#  'ahoust17',
#  'align',
#  'aslautin',
#  'bbera',
#  'bli51',
#  'bwing1',
#  'cnochese',
#  'daily align',
#  'dwilso34',
#  'edavis77',
#  'eheon',
#  'epayne19',
#  'eproehl',
#  'fanx1',
#  'fwang28',
#  'gduscher',
#  'hyu39',
#  'JBAWAH',
#  'jbrow290',
#  'jfan15',
#  'jkwon8',
#  'kbarakat',
#  'lelmont',
#  'liny',
#  'llang6',
#  'Mag_Cal_records',
#  'mkim55',
#  'mli68',
#  'mmorten1',
#  'mpalanis',
#  'mse304',
#  'mse304-2',
#  'MSE672',
#  'MSE676',
#  'MSE676-2016',
#  'MSE676-2026',
#  'MSE676-F10',
#  'ngrain',
#  'qchen23',
#  'qwang56',
#  'rthier',
#  'schen83',
#  'scopp',
#  'sdrewry',
#  'sguo19',
#  'skim172',
#  'spuplamp',
#  'ssanch18',
#  'taustin7',
#  'tsiggill',
#  'upratius',
#  'vchawla',
#  'vichawla',
#  'xfan5',
#  'yli166']

# %%
from tiled.client import from_uri

client = from_uri("http://10.46.217.241:9091", api_key="secret")

# List all files at parent directory
list(client)
# Out:
# ['0032 - Nano HAADF STEM Diffraction.emd',
#  '0033 - Nano HAADF STEM Diffraction.emd',
#  'ahoust17',
#  'align',
#  'aslautin',
#  'bbera',
#  'bli51',
#  'bwing1',
#  'cnochese',
#  'daily align',
#  'dwilso34',
#  'edavis77',
#  'eheon',
#  'epayne19',
#  'eproehl',
#  'fanx1',
#  'fwang28',
#  'gduscher',
#  'hyu39',
#  'JBAWAH',
#  'jbrow290',
#  'jfan15',
#  'jkwon8',
#  'kbarakat',
#  'lelmont',
#  'liny',
#  'llang6',
#  'Mag_Cal_records',
#  'mkim55',
#  'mli68',
#  'mmorten1',
#  'mpalanis',
#  'mse304',
#  'mse304-2',
#  'MSE672',
#  'MSE676',
#  'MSE676-2016',
#  'MSE676-2026',
#  'MSE676-F10',
#  'ngrain',
#  'qchen23',
#  'qwang56',
#  'rthier',
#  'schen83',
#  'scopp',
#  'sdrewry',
#  'sguo19',
#  'skim172',
#  'spuplamp',
#  'ssanch18',
#  'taustin7',
#  'tsiggill',
#  'upratius',
#  'vchawla',
#  'vichawla',
#  'xfan5',
#  'yli166']

# %%
# go in to user - Austin and list all files
list(client['ahoust17'])
# Out:
# ['20251209',
#  '20251229',
#  '20260204',
#  '20260209',
#  '20260212',
#  '20260312',
#  '20260316',
#  '20260414',
#  '20260421',
#  '20260423',
#  '20260501',
#  '20260508',
#  'ahoust',
#  'MoSTe_Janus2']

# %%
list(client['ahoust17']['20251209'])
# Out:
# ['MoSTe_5eV', 'MoTe2', 'ronchi']

# %%
list(client['ahoust17']['20251209']['MoSTe_5eV'])
# Out:
# ['0059 - 20251209 6.50 Mx STEM 15.4 nm.emd',
#  '0060 - 20251209 6.50 Mx STEM 15.4 nm.emd',
#  '0061 - 20251209 3.30 Mx STEM 30.8 nm.emd',
#  '0062 - 20251209 72000 x STEM 1.4 µm.emd',
#  '0063 - 20251209 72000 x STEM 1.4 µm.emd',
#  '0064 - 20251209 9.20 Mx STEM 10.9 nm.emd',
#  '0065 - 20251209 9.20 Mx STEM 10.9 nm.emd',
#  '0066 - 20251209 51000 x STEM 1.97 µm.emd',
#  '0068 - 20251209 9.20 Mx STEM 10.9 nm.emd',
#  '0069 - 20251209 3.30 Mx STEM 30.8 nm.emd',
#  '0070 - 20251209 6.50 Mx STEM 15.4 nm.emd',
#  '0071 - 20251209 810 kx STEM 123 nm.emd',
#  '0072 - 20251209 2.30 Mx STEM 43.5 nm.emd',
#  '0073 - 20251209 460 mm Camera.emd',
#  '0074 - 20251209 460 mm Camera.emd',
#  '0075 - 20251209 3.30 Mx STEM 30.8 nm.emd',
#  '0077 - 20251209 6.50 Mx STEM 15.4 nm.emd',
#  '0078 - 20251209 4.60 Mx STEM 21.8 nm.emd',
#  '0079 - 20251209 2.30 Mx STEM 43.5 nm.emd',
#  '0080 - 20251209 115 mm Spectrum.emd',
#  '0081 - 20251209 285 kx STEM 348 nm.emd',
#  '0082 - 20251209 1.65 Mx STEM 61.5 nm.emd',
#  '0086 - 20251209 1.15 Mx STEM 87 nm.emd',
#  '0087 - 20251209 1.65 Mx SI 61.5 nm.emd']

# %%
list(client['ahoust17']['20251209']['MoSTe_5eV']['0086 - 20251209 1.15 Mx STEM 87 nm.emd'])
# Out:
# ['HAADF']

# %%
client['ahoust17']['20251209']['MoSTe_5eV']['0086 - 20251209 1.15 Mx STEM 87 nm.emd']
# Out:
# {}

# %%
client['ahoust17']['20251209']['MoSTe_5eV']['0086 - 20251209 1.15 Mx STEM 87 nm.emd']["HAADF"]
# Out:
# <ArrayClient shape=(100, 512, 512) chunks=((1, 1, ..., 1), (512,), (512,)) dtype=uint16>

# %%
image = client['ahoust17']['20251209']['MoSTe_5eV']['0086 - 20251209 1.15 Mx STEM 87 nm.emd']["HAADF"][0]

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.imshow(image)

# %%
## a 512*512 image takes 0.5 seconds to be quireied in tiled ------> later benchmark with autoscript based acquisition
